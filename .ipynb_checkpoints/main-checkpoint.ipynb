# %% [markdown]
# # HumanLoop Data Challenge
# ## Alberto Raimondi

# %% [markdown]
# The task consists in performing data debugging on a model and a related dataset so that different active learning techniques can be used to increase the performance of the model with as little user input as possible.
# Due to this objective we will have to focus on a set of possible ways to rank the samples from less to most important so that the user can efficienly focus his efforts during labeling.

# %% [markdown]
# A preprocessing step on the data was performed using different techniques, data enrichment was done by querying the HumanLoop API for all the datapoints to get the predictions of the model. This is time consuming so the final dataset was serialized and saved using the piclke module.
# The preprocessing steps can be explored in the `preprocessing.py` script.

# %%
# use this to download the spacy model if not installed
# !python -m spacy download en_core_web_trf

# %%
import pandas as pd
import spacy
from collections import Counter

nlp = spacy.load("en_core_web_trf")
# %matplotlib inline

# %%
df = pd.read_pickle("./dataframe.pkl")

# %% [markdown]
# We do a small amount of data exploration, due to not having access to the gradients of the model and its parameters there is no way to implement thorough analysis techniques like saiency maps and gradient visualizations on the inputs. We will have to limit ourself to the entropy of the softmax distribution and the confidence of the model.
# We will split the task in two parts:
# 1. ranking the unlabeled datapoints
# 2. testing why labeled samples are hard to classify

# %%
#check the usage
df["usage"].unique()
# Out:
# array([None, 'training', 'testing', 'validation'], dtype=object)

# %%
df.groupby(["complete"]).count()
# Out:
#             id  usage  score  text  intent  intent_prediction  confidence
# complete
# False      193      0    193   193     193                190         190
# True      2134   2134   2134  2134    2134               2099        2099

# %% [markdown]
# We have only 193 unlabeled data points, so we a good initial way to rank them is by entropy of the model

# %%
df[df["complete"]==False].sort_values("score",ascending=False)
# Out:
#          id  complete usage     score  \
# 131  602683     False  None  1.554341
# 124  602550     False  None  0.949748
# 94   602218     False  None  0.850144
# 186  603393     False  None  0.709459
# 19   601332     False  None  0.619311
# ..      ...       ...   ...       ...
# 132  602684     False  None  0.000618
# 5    601226     False  None  0.000596
# 61   601856     False  None  0.000532
# 93   602263     False  None  0.000491
# 177  603224     False  None  0.000475
#
#                                                   text intent  \
# 131                  routing number for american river
# 124  how many times have i taken off from work this...
# 94   i wanna change my pin number for my credit acount
# 186  i cannot remember what my pin is for my bank o...
# 19       could you tell me what 30% off 235 is, please
# ..                                                 ...    ...
# 132                      switch to british male accent
# 5    i think the charge for uber on my account is f...
# 61   someone misused my card and put fraudulent tra...
# 93                    my card is to be reported stolen
# 177                       please report my stolen card
#
#     intent_prediction  confidence
# 131          finances    0.987689
# 124              None         NaN
# 94               None         NaN
# 186     chat_settings    0.706303
# 19         calculator    0.583609
# ..                ...         ...
# 132     chat_settings    0.995944
# 5          card_issue    0.997360
# 61         card_issue    0.997723
# 93         card_issue    0.997981
# 177        card_issue    0.998046
#
# [193 rows x 8 columns]

# %% [markdown]
# We can also notice that the model often does not give back a prediction, this issue may be related to the confidence of the prediction being under a threshold and stopped from getting served by the API.
# For this reason prioritizing the labeling and checking of items that are not getting an ouput may be wise.
# This may be a problem of the API request step having a bug but after manual investigation it does not seem to be the case.

# %%
df[df["intent_prediction"].isna()].sort_values("score",ascending=False)
# Out:
#           id  complete       usage     score  \
# 646   601409      True    training  1.520790
# 1635  601940      True     testing  1.451263
# 292   602035      True    training  1.289565
# 465   602646      True    training  1.267579
# 528   601257      True    training  1.263117
# 1644  602149      True     testing  1.214983
# 2206  602944      True     testing  1.152281
# 2263  601162      True    training  1.150801
# 1842  603269      True    training  1.149448
# 670   602117      True    training  1.134336
# 1473  603372      True    training  1.134336
# 689   602026      True    training  1.130585
# 946   601396      True    training  1.114125
# 1292  601660      True    training  1.068006
# 498   601558      True    training  1.060423
# 1057  602109      True    training  1.043744
# 1531  603067      True  validation  1.018209
# 990   602113      True    training  1.018209
# 2259  603290      True    training  1.003754
# 730   603282      True    training  0.988353
# 2208  602970      True     testing  0.979136
# 257   602447      True     testing  0.972293
# 256   603110      True     testing  0.966130
# 124   602550     False        None  0.949748
# 2022  602305      True    training  0.937207
# 218   602895      True    training  0.913569
# 722   602933      True    training  0.894921
# 1718  601508      True    training  0.893267
# 1753  601395      True    training  0.889218
# 395   603094      True     testing  0.871961
# 1799  601487      True    training  0.856851
# 94    602218     False        None  0.850144
# 1825  602019      True    training  0.833976
# 385   601335      True  validation  0.833976
# 1039  602923      True    training  0.809630
# 680   602432      True    training  0.767118
# 1029  602370      True    training  0.658411
# 6     601229     False        None  0.611534
#
#                                                    text           intent  \
# 646                                                undo       card_issue
# 1635  what's the due date for my american express pa...    bill_question
# 292                        what is 10 to the 12th power       calculator
# 465                    what is the square root of 10294       calculator
# 528                                    when is visa due    bill_question
# 1644                    time zone in miami is what like    international
# 2206                              what is my fica score  credit_question
# 2263          how many points did i get on my visa card  credit_question
# 1842           do a car payment from my savings account         finances
# 670                                                mute    chat_settings
# 1473                                               mute  new_application
# 689   please cancel what you are doing, i've changed...       card_issue
# 946   i need to know the number of days off i have t...     work_inquiry
# 1292                                          stop that       card_issue
# 498                        add twelve and twelve please       calculator
# 1057                        tell me about today weather       card_issue
# 1531                        what's my visa card's limit  credit_question
# 990                         what's my visa card's limit         finances
# 2259    i need you to help me with some math if you can       calculator
# 730       how many delta miles are on my card right now  rewards_related
# 2208                   what is 005 percent of 1 percent       calculator
# 257   please let me know when i need to renew my cre...       card_issue
# 256   can you tell me the minimum amount due on my v...    bill_question
# 124   how many times have i taken off from work this...
# 2022  how many points do i need before i can redeem ...  rewards_related
# 218       what's the last date i can use my credit card       card_issue
# 722   what routing number do i use to send an intern...         finances
# 1718                                what is 8 factorial       calculator
# 1753  check to see how many days off i have used in ...     work_inquiry
# 395   remind me of the invoice total for my plumbing...    bill_question
# 1799                  how long to replace a credit card       card_issue
# 94    i wanna change my pin number for my credit acount
# 1825            i want you to cancel the current action  new_application
# 385             i want you to cancel the current action    chat_settings
# 1039  i gotta change my pin number for my debit account    chat_settings
# 680   i see a purchase on my chase checking that i d...       card_issue
# 1029           do you know what the timezone is in reno    chat_settings
# 6     can you submit a pto request for me from dates...
#
#      intent_prediction  confidence
# 646               None         NaN
# 1635              None         NaN
# 292               None         NaN
# 465               None         NaN
# 528               None         NaN
# 1644              None         NaN
# 2206              None         NaN
# 2263              None         NaN
# 1842              None         NaN
# 670               None         NaN
# 1473              None         NaN
# 689               None         NaN
# 946               None         NaN
# 1292              None         NaN
# 498               None         NaN
# 1057              None         NaN
# 1531              None         NaN
# 990               None         NaN
# 2259              None         NaN
# 730               None         NaN
# 2208              None         NaN
# 257               None         NaN
# 256               None         NaN
# 124               None         NaN
# 2022              None         NaN
# 218               None         NaN
# 722               None         NaN
# 1718              None         NaN
# 1753              None         NaN
# 395               None         NaN
# 1799              None         NaN
# 94                None         NaN
# 1825              None         NaN
# 385               None         NaN
# 1039              None         NaN
# 680               None         NaN
# 1029              None         NaN
# 6                 None         NaN

# %% [markdown]
# Let's check the labeled samples that the model has misclassified, there are only 86 of them.

# %%
df["misclassified"] = df["intent"] != df["intent_prediction"]
df_gt = df[df["intent"] != ""]
df_gt = df_gt[df_gt["intent_prediction"].isna()==False]

df_gt.groupby("misclassified").count()
# Out:
#                  id  complete  usage  score  text  intent  intent_prediction  \
# misclassified
# False          2013      2013   2013   2013  2013    2013               2013
# True             86        86     86     86    86      86                 86
#
#                confidence
# misclassified
# False                2013
# True                   86

# %%
df_gt[df_gt['misclassified']==True]
# Out:
#           id  complete     usage     score  \
# 223   602784      True  training  0.707323
# 224   603364      True   testing  0.747109
# 226   602996      True  training  0.817582
# 252   601451      True   testing  0.006338
# 255   602979      True   testing  0.026765
# ...      ...       ...       ...       ...
# 2224  602761      True   testing  0.028711
# 2244  602708      True   testing  1.049908
# 2250  601853      True   testing  0.558031
# 2282  602701      True  training  0.943116
# 2311  602565      True  training  0.802394
#
#                                                    text           intent  \
# 223              what is the turn around for a new card       card_issue
# 224                       how many days did i skip work     work_inquiry
# 226         can you tell me today's rate for cad to usd    international
# 252                    what day is my car insurance due    bill_question
# 255                          what is my credit limit at         finances
# ...                                                 ...              ...
# 2224        i need to know my spending limit on my visa         finances
# 2244   i have how many tier credits on my caesar's card  rewards_related
# 2250         when can i receive rewards on my visa card  rewards_related
# 2282  how much am i allowed to spend on my discover ...         finances
# 2311           tell me the status of my day off request     work_inquiry
#
#        intent_prediction  confidence  misclassified
# 223      new_application    0.719321           True
# 224      new_application    0.714219           True
# 226        rates_related    0.598865           True
# 252   insurance_question    0.988314           True
# 255      credit_question    0.968921           True
# ...                  ...         ...            ...
# 2224     credit_question    0.971642           True
# 2244     credit_question    0.542017           True
# 2250          card_issue    0.579144           True
# 2282     credit_question    0.715600           True
# 2311     new_application    0.598675           True
#
# [86 rows x 9 columns]

# %% [markdown]
# There are high confidence items that are misclassified, the entropy seems to be better at representing when the model is not sure.

# %%
df_gt[df_gt["misclassified"]]
# Out:
#           id  complete     usage     score  \
# 223   602784      True  training  0.707323
# 224   603364      True   testing  0.747109
# 226   602996      True  training  0.817582
# 252   601451      True   testing  0.006338
# 255   602979      True   testing  0.026765
# ...      ...       ...       ...       ...
# 2224  602761      True   testing  0.028711
# 2244  602708      True   testing  1.049908
# 2250  601853      True   testing  0.558031
# 2282  602701      True  training  0.943116
# 2311  602565      True  training  0.802394
#
#                                                    text           intent  \
# 223              what is the turn around for a new card       card_issue
# 224                       how many days did i skip work     work_inquiry
# 226         can you tell me today's rate for cad to usd    international
# 252                    what day is my car insurance due    bill_question
# 255                          what is my credit limit at         finances
# ...                                                 ...              ...
# 2224        i need to know my spending limit on my visa         finances
# 2244   i have how many tier credits on my caesar's card  rewards_related
# 2250         when can i receive rewards on my visa card  rewards_related
# 2282  how much am i allowed to spend on my discover ...         finances
# 2311           tell me the status of my day off request     work_inquiry
#
#        intent_prediction  confidence  misclassified
# 223      new_application    0.719321           True
# 224      new_application    0.714219           True
# 226        rates_related    0.598865           True
# 252   insurance_question    0.988314           True
# 255      credit_question    0.968921           True
# ...                  ...         ...            ...
# 2224     credit_question    0.971642           True
# 2244     credit_question    0.542017           True
# 2250          card_issue    0.579144           True
# 2282     credit_question    0.715600           True
# 2311     new_application    0.598675           True
#
# [86 rows x 9 columns]

# %% [markdown]
# Let's check if the entropy of the misclassified items is different from the entropy of the correct ones.
# We do the same from the confidence and we notice that the entropy is a much more representative measure of the goodness of a prediction.
# This may be to the way the confidence is computed, as it is more representative of the variance of the distribution rather than an estimate of the actual confidence of the model.
#
# Due to this reason we will prefer to consider the entropy as a good measure of uncertianty instead of the confidence.

# %%
print(df_gt[df_gt["misclassified"]]["score"].mean())
print(df_gt[df_gt["misclassified"]==False]["score"].mean())
# Out:
# 0.3849888912044724
# 0.04920660238030606

# %%
print(df_gt[df_gt["misclassified"]]["confidence"].mean())
print(df_gt[df_gt["misclassified"]==False]["confidence"].mean())
# Out:
# 0.7915311192357263
# 0.958349577183162

# %% [markdown]
# We plot the distribution of the entropy and we see that is mostly composed of low values.

# %%
df["score"].plot.kde(bw_method=0.3)

# %% [markdown]
# By splitting it by misclassified examples we see that the distribution of the misclassified ones has a higher entropy and variance.

# %%
df_temp = df[df["misclassified"]==True]
df_temp["score"].plot.kde(bw_method=0.3)
df_temp = df[df["misclassified"]==False]
df_temp["score"].plot.kde(bw_method=0.3)

# %% [markdown]
# We will now check how the intent influences the confidence of the model by plotting its variance and standard deviation for all the intents.
#
# We can see that the calculator intent seems to be all over the place with a high standard deviation.
# This may be due to the numbers being treated in a specific way by the model.
#
# Both the new_application and the finances question intent have a high average and variance, this could be intuitevly motivated by the broad meaning of these two categories.
#
# A possible interesting way to improve the data would be to split these intents into more specific categories, or in alternative increasing their number of samples.

# %%
df_intent = pd.DataFrame()
df_intent["intent"] = df.groupby("intent").groups.keys()
df_intent["num"] = df.groupby("intent", as_index=False).count()["complete"]
df_intent["sum"] = df.groupby("intent")["score"].sum().values
df_intent["average"] = df.groupby("intent")["score"].mean().values
df_intent["std"] = df.groupby("intent")["score"].std().values

df_intent.sort_values("average", ascending=False)

df_intent.plot.bar("intent", ["average", "std"])

# %% [markdown]
# We check if the model is converged, we don't have access to the full probability distribution of the output so we cannot compute the cross entropy loss. However the ouput entropy could be a good approximation of it.
# We see that the entropy on training and validation dataset is lower than the testing one. This suggests that the model is not fully converged or it lacks the capacity to generalize to the test set. More training or a bigger model may help the performance.
# Also due to the phenomenon of the double descent an increase in capacity of the model could lead to much higher generalization performance.
#
# Another thing this plot suggests is that the validation set may have been used to much and was manually overfitted. Further investigations on the model are warranted.

# %%
df.groupby("usage", as_index=False).mean().plot.bar("usage", "score")

# %% [markdown]
# We use an external mode to do a small part of speech analysis on the text given to the model.
# We avoid weighting the samples by their entropy and we just select a threshold value to split the data.
# We can see that high entropy samples have more numbers, indicating again that they should be considered in a special way.
#
# Low entropy samples have more verbs and pronouns, meaning that they may be useful to improve the model performance.

# %%
def get_pos_counts(string):
    doc = nlp(string)
    pos_list = [token.pos_ for token in doc]
    return dict(Counter(pos_list))

# %%
df['text_len']= df['text'].apply(lambda x:len(x.split()))

# %%
df['pos_count']= df['text'].apply(get_pos_counts)
df_high_entropy = df[df["score"]>0.05]# this threshold can be an hyperparameter
df_low_entropy = df[df["score"]<=0.05]

pos_list_high = df_high_entropy["pos_count"].tolist()
pos_list_low = df_low_entropy["pos_count"].tolist()

# %%
counter = Counter()
for d in pos_list_high: 
    counter.update(d)
      
count_high_entropy_pos = dict(counter)

counter = Counter()
for d in pos_list_low: 
    counter.update(d)
      
count_low_entropy_pos = dict(counter)

# %%
low_entropy_pos_average = {k:v/len(df_low_entropy) for k,v in count_low_entropy_pos.items()}
high_entropy_pos_average = {k:v/len(df_high_entropy) for k,v in count_high_entropy_pos.items()}

# %%
import matplotlib.pyplot as plt
plt.bar(*zip(*low_entropy_pos_average.items()),label= "low entropy")
plt.bar(*zip(*high_entropy_pos_average.items()),label="high entropy")


plt.xticks( rotation='vertical')
plt.legend()
plt.show()

# %% [markdown]
# We check some statistics about the distribution of the length of the input sentence.
# It does not seem to affect the misclassification rate much.

# %%
df["text_len"].plot.kde(bw_method=0.3)

# %%
df_temp = df[df["misclassified"]==True]
df_temp["text_len"].plot.kde(bw_method=0.3)
df_temp = df[df["misclassified"]==False]
df_temp["text_len"].plot.kde(bw_method=0.3)

# %%
df_high_entropy["text_len"].plot.kde(bw_method=0.3)
df_low_entropy["text_len"].plot.kde(bw_method=0.3)

# %% [markdown]
# ## Conclusion
#
# In this task we applied various techniques to explore the dataset and its interaction with the model with the aim of finding ways to improve the data.
# We first ranked the unlabeled examples according to the entropy, this was assumed to be a good measure of the difficulty of the data point after some brief descriptive stastistics computed on the data. Due to the very low number of unlabeled data points more analysis on them may be not be representative of their actual impact on the model.
# For the part of manual data augmentation we explored various criteria by which new data could be added. To do this we focused on exploring which variables influence more the accuracy and confidence of the model in a prediction.
#
# Various other possible techniques are applicable to this analysis, some including precomputed word embeddings or active inference using transformers models.
# This was not implemented in this work for two reasons:
# The aggregation and analisys of word embeddings, especially when using a weighting coefficient (like the entropy in our case) often proves to be sub-optimal and hard to implement in a reliable way. The linear nature of precomputed embeddings often leads to any aggregate measure being hardly informative about the actual data.
#
# Additionally due to the low volume of the data applying these high dimensionality techniques may be counterproductive.
#
# The final reccomendation to improve the dataset are the follwing:
#
# 1. Change how the numbers are represented in the model, the mere presence of a number instead on its value may be much more indicative of the intent of the input.
#
# 2. Split the intents "new_application" and "finances" into more specific categories, they are very broad and tend to be the hardest to correctly predict. In alternative getting more datapoints for this categories could be beneficial
#
# 3. If new samples will be manually crafted prefer ones with less verbs and pronouns, the model has some difficulties to deal with samples without these parts of speech an giving it more hard samples should improve its performance
#
# 4. On the model side an increase in model size or in its capacity and training time may prove beneficial. Also the reduction of the number of regularization techniques applied may be beneficial.
#
# 5. The length of the input text seems to not influence the result much so it is of low interest for this task.
#
# The time take for this analysis was of 4 hours and 15 minutes.
